# %% [markdown]
# # 성명

# %% [markdown]
# ## 공상균

# %% [markdown]
# # 1 번 문제 답

# %%
def list_sum(list):
    temp = 0
    for i in list:
        temp +=i
    return temp

list_sum([1,2,3,4,5])
# Out:
# 15

# %% [markdown]
# # 2번 문제 답

# %%
def gugudan(num):
    if (num<2) | (num>9):
        print("잘못된 숫자를 입력하였습니다.")
    else:
        for i in range(9):
            print("{} X {} = {}".format(num,i+1,num*(i+1)))

gugudan(2)
gugudan(10)
# Out:
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
# 잘못된 숫자를 입력하였습니다.

# %% [markdown]
# # 3번 문제 답

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

url = "https://finance.naver.com/marketindex/exchangeDailyQuote.nhn?marketindexCd=FX_USDKRW&page="

dates = []
nums = []
for i in range(5):
    url_pg = url + str(1)
    response = requests.get(url_pg,headers = request_headers)
    soup = BeautifulSoup(response.text, "html.parser")
    result_date= soup.find_all("td",class_="date")
    result_num= soup.find_all("td",class_="num")
    for i in result_date:
        dates.append(i.text)
    for i in result_num:
        nums.append(i.text)
numss = []
for i in range(100):
    if i%2 == 0:
        numss.append(nums[i])


a = {"일자": dates, "환율" : numss}

df = pd.DataFrame(a)

print(df)
# Out:
#             일자        환율
# 0   2021.06.02  1,108.30
# 1   2021.06.01  1,109.50
# 2   2021.05.31  1,108.50
# 3   2021.05.28  1,115.00
# 4   2021.05.27  1,117.00
# 5   2021.05.26  1,117.00
# 6   2021.05.25  1,123.00
# 7   2021.05.24  1,126.50
# 8   2021.05.21  1,127.50
# 9   2021.05.20  1,132.50
# 10  2021.06.02  1,108.30
# 11  2021.06.01  1,109.50
# 12  2021.05.31  1,108.50
# 13  2021.05.28  1,115.00
# 14  2021.05.27  1,117.00
# 15  2021.05.26  1,117.00
# 16  2021.05.25  1,123.00
# 17  2021.05.24  1,126.50
# 18  2021.05.21  1,127.50
# 19  2021.05.20  1,132.50
# 20  2021.06.02  1,108.30
# 21  2021.06.01  1,109.50
# 22  2021.05.31  1,108.50
# 23  2021.05.28  1,115.00
# 24  2021.05.27  1,117.00
# 25  2021.05.26  1,117.00
# 26  2021.05.25  1,123.00
# 27  2021.05.24  1,126.50
# 28  2021.05.21  1,127.50
# 29  2021.05.20  1,132.50
# 30  2021.06.02  1,108.30
# 31  2021.06.01  1,109.50
# 32  2021.05.31  1,108.50
# 33  2021.05.28  1,115.00
# 34  2021.05.27  1,117.00
# 35  2021.05.26  1,117.00
# ...

# %% [markdown]
# # 4번 문제 답

# %%
import matplotlib.pyplot as plt
import numpy as np

list_num = []
for i in range(20):
    list_num.append(np.random.randint(30,100))

plt.plot(list_num)
plt.title("random number")
plt.show()
